# %%
import csv
from csv import DictReader
from collections import defaultdict
reader = DictReader(open('prebivalstvo-SLO.csv', 'rt', encoding='utf-8'))

for vrsta in reader:
    obcina=vrsta["MUNICIPALITIES"]
    if obcina=="Škofja Loka":
        print(vrsta.get(fieldname))

# %%
Imena Stolpcev

# %%
with open('prebivalstvo-SLO.csv', 'rt', encoding='utf-8') as f:
    d_reader = csv.DictReader(f)
    headers = d_reader.fieldnames

# %%
headers

# %%
Izpiše samo vrednosti izbranih stolpcev v included_cols

# %%
included_cols = ['1995 Natural increase']
reader = DictReader(open('prebivalstvo-SLO.csv', 'rt', encoding='utf-8'))
for row in reader:
    obcina=row["MUNICIPALITIES"]
    if obcina=="Škofja Loka":
        content = list(row[i] for i in included_cols)
        print (content)
# Out:
# ['81']
